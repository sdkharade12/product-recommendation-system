# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# df = pd.read_json(r'../data/reviews_Electronics_5.json.gz', lines = True)

# %%
# df

# %%
'''import gzip
import json

with gzip.open('../data/meta_Electronics.jsonl.gz', 'rt', encoding='utf-8') as f:
    first_line = json.loads(next(f))

print(first_line)'''
# Out:
# "import gzip\nimport json\n\nwith gzip.open('../data/meta_Electronics.jsonl.gz', 'rt', encoding='utf-8') as f:\n    first_line = json.loads(next(f))\n\nprint(first_line)"

# %%
# print(first_line.keys())

# %%
'''data = []

with gzip.open('../data/meta_Electronics.jsonl.gz', 'rt', encoding='utf-8') as f:
    for line in f:
        obj = json.loads(line)

        data.append({
            "asin": obj.get("parent_asin"),
            "title": obj.get("title"),
            "brand": obj.get("store"),
            "category": obj.get("categories"),
            "description": obj.get("description"),
            "avg_rating": obj.get("average_rating"),
            "rating_count": obj.get("rating_number"),
            "bought_together": obj.get("bought_together")
        })

df_meta = pd.DataFrame(data)'''
# Out:
# 'data = []\n\nwith gzip.open(\'../data/meta_Electronics.jsonl.gz\', \'rt\', encoding=\'utf-8\') as f:\n    for line in f:\n        obj = json.loads(line)\n\n        data.append({\n            "asin": obj.get("parent_asin"),\n            "title": obj.get("title"),\n            "brand": obj.get("store"),\n            "category": obj.get("categories"),\n            "description": obj.get("description"),\n            "avg_rating": obj.get("average_rating"),\n            "rating_count": obj.get("rating_number"),\n            "bought_together": obj.get("bought_together")\n        })\n\ndf_meta = pd.DataFrame(data)'

# %%
# df_meta

# %%
# df

# %%
# df_final = df.merge(df_meta, on="asin", how="inner")

# %%
# df_final.head()

# %%
# df_final.shape

# %%
# df_final['bought_together'].unique()

# %%
# df_final.to_csv('Final_Merged_Raw_Dataset.csv', index = False)

# %%
df1 = pd.read_csv(r'../data/Final_Merged_Raw_Dataset.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df1 = pd.read_csv(r'../data/Final_Merged_Raw_Dataset.csv')
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File pandas/_libs/parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File pandas/_libs/parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File pandas/_libs/parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File pandas/_libs/parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File pandas/_libs/parsers.pyx:2061, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %%
df1.head()
# Out:
#        reviewerID        asin              reviewerName   helpful  \
# 0   AO94DHGC771SJ  0528881469                   amazdnu    [0, 0]
# 1   AMO214LNFCEI4  0528881469           Amazon Customer  [12, 15]
# 2  A3N7T0DY83Y4IG  0528881469             C. A. Freeman  [43, 45]
# 3  A1H8PY3QHMQQA0  0528881469  Dave M. Shaw "mack dave"   [9, 10]
# 4  A24EV6RXELQZ63  0528881469               Wayne Smith    [0, 0]
#
#                                           reviewText  overall  \
# 0  We got this GPS for my husband who is an (OTR)...        5
# 1  I'm a professional OTR truck driver, and I bou...        1
# 2  Well, what can I say.  I've had this unit in m...        3
# 3  Not going to write a long review, even thought...        2
# 4  I've had mine for a year and here's what we go...        1
#
#                                   summary  unixReviewTime   reviewTime  \
# 0                         Gotta have GPS!      1370131200   06 2, 2013
# 1                       Very Disappointed      1290643200  11 25, 2010
# 2                          1st impression      1283990400   09 9, 2010
# 3                 Great grafics, POOR GPS      1290556800  11 24, 2010
# 4  Major issues, only excuses for support      1317254400  09 29, 2011
#
#                                                title         brand  \
# 0  Rand McNally 528881469 7-inch Intelliroute TND...  Rand McNally
# 1  Rand McNally 528881469 7-inch Intelliroute TND...  Rand McNally
# 2  Rand McNally 528881469 7-inch Intelliroute TND...  Rand McNally
# 3  Rand McNally 528881469 7-inch Intelliroute TND...  Rand McNally
# 4  Rand McNally 528881469 7-inch Intelliroute TND...  Rand McNally
#
#                                             category  \
# 0  ['Electronics', 'GPS, Finders & Accessories', ...
# 1  ['Electronics', 'GPS, Finders & Accessories', ...
# 2  ['Electronics', 'GPS, Finders & Accessories', ...
# 3  ['Electronics', 'GPS, Finders & Accessories', ...
# 4  ['Electronics', 'GPS, Finders & Accessories', ...
#
#                                          description  avg_rating  \
# 0  ['Product description', '**** Shipped by 2-3 D...         3.6
# 1  ['Product description', '**** Shipped by 2-3 D...         3.6
# 2  ['Product description', '**** Shipped by 2-3 D...         3.6
# 3  ['Product description', '**** Shipped by 2-3 D...         3.6
# 4  ['Product description', '**** Shipped by 2-3 D...         3.6
#
#    rating_count  bought_together
# 0            73              NaN
# 1            73              NaN
# 2            73              NaN
# 3            73              NaN
# 4            73              NaN

# %% [markdown]
# ### EDA

# %%
df1.shape
# Out:
# (903720, 16)

# %%
df1.isna().sum()
# Out:
# reviewerID              0
# asin                    0
# reviewerName        12061
# helpful                 0
# reviewText            548
# overall                 0
# summary                 9
# unixReviewTime          0
# reviewTime              0
# title                  14
# brand                1938
# category                0
# description             0
# avg_rating              0
# rating_count            0
# bought_together    903720
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %%
df1.drop(columns = ['bought_together'], inplace = True)

# %%
df1.shape
# Out:
# (903720, 15)

# %%
df1.drop(columns = ['reviewerName'], inplace = True)

# %%
df1 = df1.drop(columns=[
    'reviewerID',
    'asin',
    'helpful',
    'overall',
    'summary',
    'unixReviewTime',
    'reviewTime',
    'avg_rating',
    'rating_count'
])

# %%
df1.head()
# Out:
#                                           reviewText  \
# 0  We got this GPS for my husband who is an (OTR)...
# 1  I'm a professional OTR truck driver, and I bou...
# 2  Well, what can I say.  I've had this unit in m...
# 3  Not going to write a long review, even thought...
# 4  I've had mine for a year and here's what we go...
#
#                                                title         brand  \
# 0  Rand McNally 528881469 7-inch Intelliroute TND...  Rand McNally
# 1  Rand McNally 528881469 7-inch Intelliroute TND...  Rand McNally
# 2  Rand McNally 528881469 7-inch Intelliroute TND...  Rand McNally
# 3  Rand McNally 528881469 7-inch Intelliroute TND...  Rand McNally
# 4  Rand McNally 528881469 7-inch Intelliroute TND...  Rand McNally
#
#                                             category  \
# 0  ['Electronics', 'GPS, Finders & Accessories', ...
# 1  ['Electronics', 'GPS, Finders & Accessories', ...
# 2  ['Electronics', 'GPS, Finders & Accessories', ...
# 3  ['Electronics', 'GPS, Finders & Accessories', ...
# 4  ['Electronics', 'GPS, Finders & Accessories', ...
#
#                                          description
# 0  ['Product description', '**** Shipped by 2-3 D...
# 1  ['Product description', '**** Shipped by 2-3 D...
# 2  ['Product description', '**** Shipped by 2-3 D...
# 3  ['Product description', '**** Shipped by 2-3 D...
# 4  ['Product description', '**** Shipped by 2-3 D...

# %%
df1.shape
# Out:
# (903720, 5)

# %%
df1.isna().sum()
# Out:
# reviewText      548
# title            14
# brand          1938
# category          0
# description       0
# dtype: int64

# %%
df1['reviewText'] = df1['reviewText'].fillna('')

# %%
df1 = df1.dropna(subset = ['title'])

# %%
df1['brand'].unique()
# Out:
# array(['Rand McNally', 'Barnes & Noble', 'VideoSecu', ..., 'AUSDOM',
#        'TaoTronics', 'Ritz Gear'], shape=(4800,), dtype=object)

# %%
df1.isna().sum()
# Out:
# reviewText        0
# title             0
# brand          1938
# category          0
# description       0
# dtype: int64

# %%
df1['brand'] = df1['brand'].fillna('')

# %%
df1.isna().sum()
# Out:
# reviewText     0
# title          0
# brand          0
# category       0
# description    0
# dtype: int64

# %%
df1.head()
# Out:
#                                           reviewText  \
# 0  We got this GPS for my husband who is an (OTR)...
# 1  I'm a professional OTR truck driver, and I bou...
# 2  Well, what can I say.  I've had this unit in m...
# 3  Not going to write a long review, even thought...
# 4  I've had mine for a year and here's what we go...
#
#                                                title         brand  \
# 0  Rand McNally 528881469 7-inch Intelliroute TND...  Rand McNally
# 1  Rand McNally 528881469 7-inch Intelliroute TND...  Rand McNally
# 2  Rand McNally 528881469 7-inch Intelliroute TND...  Rand McNally
# 3  Rand McNally 528881469 7-inch Intelliroute TND...  Rand McNally
# 4  Rand McNally 528881469 7-inch Intelliroute TND...  Rand McNally
#
#                                             category  \
# 0  ['Electronics', 'GPS, Finders & Accessories', ...
# 1  ['Electronics', 'GPS, Finders & Accessories', ...
# 2  ['Electronics', 'GPS, Finders & Accessories', ...
# 3  ['Electronics', 'GPS, Finders & Accessories', ...
# 4  ['Electronics', 'GPS, Finders & Accessories', ...
#
#                                          description
# 0  ['Product description', '**** Shipped by 2-3 D...
# 1  ['Product description', '**** Shipped by 2-3 D...
# 2  ['Product description', '**** Shipped by 2-3 D...
# 3  ['Product description', '**** Shipped by 2-3 D...
# 4  ['Product description', '**** Shipped by 2-3 D...

# %%
df1 = df1.groupby('title').agg({
    'description': 'first',
    'category': 'first',
    'brand': 'first',
    'reviewText': ' '.join
}).reset_index()

# %%
df1.shape
# Out:
# (39936, 5)

# %%
df1
# Out:
#                                                    title  \
# 0      "C" Size Battery Shell Adapter for AA Batterie...
# 1      "D" Size Battery Shell Adapter for AA Batterie...
# 2      (1 Pair) Universal satellite surround sound sp...
# 3      (10 Packs) Fotasy Stainless Steel 3/8" to 1/4"...
# 4      (10 Pcs Bundle) 5 Center Pinch Lens Cap (55mm)...
# ...                                                  ...
# 39931  welspo Wireless USB Handheld Finger Trackball ...
# 39932                       xPrintServer Network Edition
# 39933  zBoost YX039-PCS-CEL Dual Band Directional Out...
# 39934  ~Upek Eikon Trueme - Fingerprint reader - USB ...
# 39935  “Discontinued by Manufacturer” D-Link Smart Pl...
#
#                                              description  \
# 0      ['Using the PROAA2C c-size adapter you can pow...
# 1      ['Using the PROAA2D d-size adapter you can pow...
# 2      ['Speaker Wall Mounting Bracket - Black or Sil...
# 3      ['These 1/4" to 3/8" Screw Adapter Converter R...
# 4                                                     []
# ...                                                  ...
# 39931                                                 []
# 39932  ["xPrintServer is an easy-to-use, affordable '...
# 39933  ['The YX039-PCS-CEL dual-band outdoor signal a...
# 39934  ["With this UPEK Eikon TrueMe USB Fingerprint ...
# 39935  ['The mydlink Wi-Fi Smart Plug (DSP-W215) is a...
#
#                                                 category      brand  \
# 0      ['Electronics', 'Power Accessories', 'AC Adapt...     Lenmar
# 1      ['Electronics', 'Power Accessories', 'AC Adapt...     Lenmar
# 2      ['Electronics', 'Accessories & Supplies', 'Mou...  EZ Mounts
# 3                      ['Electronics', 'Camera & Photo']     Fotasy
# 4      ['Electronics', 'Camera & Photo', 'Accessories...       WAAO
# ...                                                  ...        ...
# 39931  ['Electronics', 'Computers & Accessories', 'Co...     welspo
# 39932  ['Electronics', 'Computers & Accessories', 'La...  Lantronix
# 39933  ['Electronics', 'Television & Video', 'Accesso...     zBoost
# 39934  ['Electronics', 'Security & Surveillance', 'Bi...      Eikon
# 39935  ['Electronics', 'Computers & Accessories', 'Ne...     D-Link
#
#                                               reviewText
# 0      Does what it says on the tin. Fits neatly and ...
# 1      I have these in a baby swing since buying a 4 ...
# 2      I have a Bose Cinemate system (original), whic...
# 3      I bought these to install DMKPhoto Heavy Duty ...
# 4      Every photographer needs spare lens caps. This...
# ...                                                  ...
# 39931  I had been using the wired version of this mou...
# 39932  Although I am very computer savvy, I didn't qu...
# 39933  was told to order this to help amp. did not ma...
# 39934  This device does not work with Windows 7. It d...
# 39935  ---Update 5-23-2014----------The plugs were ab...
#
# [39936 rows x 5 columns]

# %%
# Extracting the text from description column

import ast

def clean_description(text):
    try:
        lst = ast.literal_eval(text)  # convert string → list
        if isinstance(lst, list):
            return ' '.join(lst)  # join list elements
        return text
    except:
        return ''

df1['description'] = df1['description'].apply(clean_description)

# %%
# Extracting the text from category column
import ast

def clean_category(text):
    try:
        lst = ast.literal_eval(text)
        if isinstance(lst, list):
            return ' '.join(lst)
        return text
    except:
        return ''

df1['category'] = df1['category'].apply(clean_category)

# %%
df1.head()
# Out:
#                                                title  \
# 0  "C" Size Battery Shell Adapter for AA Batterie...
# 1  "D" Size Battery Shell Adapter for AA Batterie...
# 2  (1 Pair) Universal satellite surround sound sp...
# 3  (10 Packs) Fotasy Stainless Steel 3/8" to 1/4"...
# 4  (10 Pcs Bundle) 5 Center Pinch Lens Cap (55mm)...
#
#                                          description  \
# 0  Using the PROAA2C c-size adapter you can power...
# 1  Using the PROAA2D d-size adapter you can power...
# 2  Speaker Wall Mounting Bracket - Black or Silve...
# 3  These 1/4" to 3/8" Screw Adapter Converter Red...
# 4
#
#                                             category      brand  \
# 0          Electronics Power Accessories AC Adapters     Lenmar
# 1          Electronics Power Accessories AC Adapters     Lenmar
# 2  Electronics Accessories & Supplies Mounts Spea...  EZ Mounts
# 3                         Electronics Camera & Photo     Fotasy
# 4  Electronics Camera & Photo Accessories Lens Ac...       WAAO
#
#                                           reviewText
# 0  Does what it says on the tin. Fits neatly and ...
# 1  I have these in a baby swing since buying a 4 ...
# 2  I have a Bose Cinemate system (original), whic...
# 3  I bought these to install DMKPhoto Heavy Duty ...
# 4  Every photographer needs spare lens caps. This...

# %%
df1['combined_text'] = (
    df1['title'] + " " +
    df1['description'] + " " +
    df1['category'] + " " +
    df1['brand'] + " " +
    df1['reviewText']
)

# %%
import re
def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z0-9\s]', '', text)  # remove special chars
    return text
df1['combined_text'] = df1['combined_text'].apply(clean_text)

# %%
df1.head()
# Out:
#                                                title  \
# 0  "C" Size Battery Shell Adapter for AA Batterie...
# 1  "D" Size Battery Shell Adapter for AA Batterie...
# 2  (1 Pair) Universal satellite surround sound sp...
# 3  (10 Packs) Fotasy Stainless Steel 3/8" to 1/4"...
# 4  (10 Pcs Bundle) 5 Center Pinch Lens Cap (55mm)...
#
#                                          description  \
# 0  Using the PROAA2C c-size adapter you can power...
# 1  Using the PROAA2D d-size adapter you can power...
# 2  Speaker Wall Mounting Bracket - Black or Silve...
# 3  These 1/4" to 3/8" Screw Adapter Converter Red...
# 4
#
#                                             category      brand  \
# 0          Electronics Power Accessories AC Adapters     Lenmar
# 1          Electronics Power Accessories AC Adapters     Lenmar
# 2  Electronics Accessories & Supplies Mounts Spea...  EZ Mounts
# 3                         Electronics Camera & Photo     Fotasy
# 4  Electronics Camera & Photo Accessories Lens Ac...       WAAO
#
#                                           reviewText  \
# 0  Does what it says on the tin. Fits neatly and ...
# 1  I have these in a baby swing since buying a 4 ...
# 2  I have a Bose Cinemate system (original), whic...
# 3  I bought these to install DMKPhoto Heavy Duty ...
# 4  Every photographer needs spare lens caps. This...
#
#                                        combined_text
# 0  c size battery shell adapter for aa batteries ...
# 1  d size battery shell adapter for aa batteries ...
# 2  1 pair universal satellite surround sound spea...
# 3  10 packs fotasy stainless steel 38 to 14 reduc...
# 4  10 pcs bundle 5 center pinch lens cap 55mm and...

# %%
# %pip install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.3.0-py3-none-any.whl (512 kB)
#      ---------------------------------------- 0.0/512.4 kB ? eta -:--:--
#      -------------- ----------------------- 194.6/512.4 kB 5.8 MB/s eta 0:00:01
#      --------------------------------- ---- 450.6/512.4 kB 5.6 MB/s eta 0:00:01
#      -------------------------------------- 512.4/512.4 kB 4.6 MB/s eta 0:00:00
# Collecting tqdm
#   Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# Requirement already satisfied: scipy in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (4.15.0)
# Collecting torch>=1.11.0
#   Downloading torch-2.11.0-cp310-cp310-win_amd64.whl (114.5 MB)
#      ---------------------------------------- 0.0/114.5 MB ? eta -:--:--
#      ---------------------------------------- 0.2/114.5 MB 5.3 MB/s eta 0:00:22
#      ---------------------------------------- 0.2/114.5 MB 3.6 MB/s eta 0:00:32
#      ---------------------------------------- 0.2/114.5 MB 3.6 MB/s eta 0:00:32
#      ---------------------------------------- 0.2/114.5 MB 3.6 MB/s eta 0:00:32
#      ---------------------------------------- 0.5/114.5 MB 2.2 MB/s eta 0:00:51
#      ---------------------------------------- 0.5/114.5 MB 2.2 MB/s eta 0:00:51
#      ---------------------------------------- 0.6/114.5 MB 1.9 MB/s eta 0:01:00
#      ---------------------------------------- 0.7/114.5 MB 2.2 MB/s eta 0:00:53
#      ---------------------------------------- 1.0/114.5 MB 2.4 MB/s eta 0:00:47
#      ---------------------------------------- 1.0/114.5 MB 2.1 MB/s eta 0:00:54
#      ---------------------------------------- 1.0/114.5 MB 2.1 MB/s eta 0:00:54
#      ---------------------------------------- 1.2/114.5 MB 2.1 MB/s eta 0:00:54
#      ---------------------------------------- 1.2/114.5 MB 2.1 MB/s eta 0:00:54
#      ---------------------------------------- 1.2/114.5 MB 1.9 MB/s eta 0:01:01
#       --------------------------------------- 1.5/114.5 MB 2.1 MB/s eta 0:00:53
#       --------------------------------------- 1.6/114.5 MB 2.3 MB/s eta 0:00:50
#       --------------------------------------- 1.6/114.5 MB 2.3 MB/s eta 0:00:50
#       --------------------------------------- 1.9/114.5 MB 2.2 MB/s eta 0:00:51
#       --------------------------------------- 1.9/114.5 MB 2.2 MB/s eta 0:00:51
#       --------------------------------------- 2.0/114.5 MB 2.2 MB/s eta 0:00:52
#       --------------------------------------- 2.1/114.5 MB 2.1 MB/s eta 0:00:53
#       --------------------------------------- 2.2/114.5 MB 2.2 MB/s eta 0:00:53
#       --------------------------------------- 2.3/114.5 MB 2.2 MB/s eta 0:00:52
#       --------------------------------------- 2.3/114.5 MB 2.2 MB/s eta 0:00:52
#       --------------------------------------- 2.4/114.5 MB 2.1 MB/s eta 0:00:54
#       --------------------------------------- 2.5/114.5 MB 2.1 MB/s eta 0:00:55
#       --------------------------------------- 2.6/114.5 MB 2.1 MB/s eta 0:00:54
#       --------------------------------------- 2.6/114.5 MB 2.1 MB/s eta 0:00:54
#       --------------------------------------- 2.8/114.5 MB 2.1 MB/s eta 0:00:54
#      - -------------------------------------- 2.9/114.5 MB 2.1 MB/s eta 0:00:53
#      - -------------------------------------- 2.9/114.5 MB 2.0 MB/s eta 0:00:56
#      - -------------------------------------- 2.9/114.5 MB 2.0 MB/s eta 0:00:56
#      - -------------------------------------- 3.1/114.5 MB 2.0 MB/s eta 0:00:57
#      - -------------------------------------- 3.1/114.5 MB 2.0 MB/s eta 0:00:57
#      - -------------------------------------- 3.1/114.5 MB 2.0 MB/s eta 0:00:57
#      - -------------------------------------- 3.4/114.5 MB 2.0 MB/s eta 0:00:56
#      - -------------------------------------- 3.4/114.5 MB 2.0 MB/s eta 0:00:56
#      - -------------------------------------- 3.4/114.5 MB 2.0 MB/s eta 0:00:57
#      - -------------------------------------- 3.5/114.5 MB 1.9 MB/s eta 0:00:57
#      - -------------------------------------- 3.7/114.5 MB 2.0 MB/s eta 0:00:56
#      - -------------------------------------- 3.7/114.5 MB 2.0 MB/s eta 0:00:57
#      - -------------------------------------- 3.7/114.5 MB 2.0 MB/s eta 0:00:57
#      - -------------------------------------- 3.8/114.5 MB 1.9 MB/s eta 0:00:58
#      - -------------------------------------- 3.9/114.5 MB 1.9 MB/s eta 0:00:58
#      - -------------------------------------- 4.0/114.5 MB 1.9 MB/s eta 0:00:58
#      - -------------------------------------- 4.0/114.5 MB 1.9 MB/s eta 0:00:58
#      - -------------------------------------- 4.2/114.5 MB 1.9 MB/s eta 0:00:58
#      - -------------------------------------- 4.2/114.5 MB 1.9 MB/s eta 0:00:58
#      - -------------------------------------- 4.3/114.5 MB 1.9 MB/s eta 0:00:58
#      - -------------------------------------- 4.4/114.5 MB 1.9 MB/s eta 0:00:59
#      - -------------------------------------- 4.6/114.5 MB 1.9 MB/s eta 0:00:58
#      - -------------------------------------- 4.6/114.5 MB 1.9 MB/s eta 0:00:58
#      - -------------------------------------- 4.6/114.5 MB 1.9 MB/s eta 0:00:58
#      - -------------------------------------- 4.8/114.5 MB 1.9 MB/s eta 0:00:58
#      - -------------------------------------- 4.9/114.5 MB 1.9 MB/s eta 0:00:58
#      - -------------------------------------- 4.9/114.5 MB 1.9 MB/s eta 0:00:58
#      - -------------------------------------- 4.9/114.5 MB 1.9 MB/s eta 0:00:58
#      - -------------------------------------- 5.2/114.5 MB 1.9 MB/s eta 0:00:58
#      - -------------------------------------- 5.2/114.5 MB 1.9 MB/s eta 0:00:58
#      - -------------------------------------- 5.3/114.5 MB 1.9 MB/s eta 0:00:59
#      - -------------------------------------- 5.3/114.5 MB 1.9 MB/s eta 0:00:59
#      - -------------------------------------- 5.5/114.5 MB 1.9 MB/s eta 0:00:58
#      - -------------------------------------- 5.5/114.5 MB 1.9 MB/s eta 0:00:58
#      - -------------------------------------- 5.6/114.5 MB 1.9 MB/s eta 0:00:59
#      -- ------------------------------------- 5.8/114.5 MB 1.9 MB/s eta 0:00:58
#      -- ------------------------------------- 5.9/114.5 MB 1.9 MB/s eta 0:00:58
#      -- ------------------------------------- 6.0/114.5 MB 1.9 MB/s eta 0:00:58
#      -- ------------------------------------- 6.1/114.5 MB 1.9 MB/s eta 0:00:57
#      -- ------------------------------------- 6.2/114.5 MB 1.9 MB/s eta 0:00:57
#      -- ------------------------------------- 6.2/114.5 MB 1.9 MB/s eta 0:00:58
#      -- ------------------------------------- 6.3/114.5 MB 1.9 MB/s eta 0:00:58
#      -- ------------------------------------- 6.3/114.5 MB 1.9 MB/s eta 0:00:58
#      -- ------------------------------------- 6.5/114.5 MB 1.9 MB/s eta 0:00:57
#      -- ------------------------------------- 6.5/114.5 MB 1.9 MB/s eta 0:00:57
#      -- ------------------------------------- 6.7/114.5 MB 1.9 MB/s eta 0:00:57
#      -- ------------------------------------- 6.8/114.5 MB 1.9 MB/s eta 0:00:57
#      -- ------------------------------------- 6.9/114.5 MB 1.9 MB/s eta 0:00:57
#      -- ------------------------------------- 7.0/114.5 MB 1.9 MB/s eta 0:00:57
#      -- ------------------------------------- 7.2/114.5 MB 1.9 MB/s eta 0:00:56
#      -- ------------------------------------- 7.2/114.5 MB 1.9 MB/s eta 0:00:56
#      -- ------------------------------------- 7.2/114.5 MB 1.9 MB/s eta 0:00:56
#      -- ------------------------------------- 7.5/114.5 MB 1.9 MB/s eta 0:00:56
#      -- ------------------------------------- 7.5/114.5 MB 1.9 MB/s eta 0:00:56
#      -- ------------------------------------- 7.7/114.5 MB 2.0 MB/s eta 0:00:55
#      -- ------------------------------------- 7.7/114.5 MB 1.9 MB/s eta 0:00:56
#      -- ------------------------------------- 7.9/114.5 MB 2.0 MB/s eta 0:00:55
#      -- ------------------------------------- 7.9/114.5 MB 2.0 MB/s eta 0:00:55
#      -- ------------------------------------- 8.0/114.5 MB 1.9 MB/s eta 0:00:55
#      -- ------------------------------------- 8.1/114.5 MB 1.9 MB/s eta 0:00:55
#      -- ------------------------------------- 8.3/114.5 MB 2.0 MB/s eta 0:00:55
#      -- ------------------------------------- 8.3/114.5 MB 2.0 MB/s eta 0:00:55
#      -- ------------------------------------- 8.3/114.5 MB 2.0 MB/s eta 0:00:55
#      -- ------------------------------------- 8.5/114.5 MB 2.0 MB/s eta 0:00:55
#      --- ------------------------------------ 8.7/114.5 MB 2.0 MB/s eta 0:00:55
#      --- ------------------------------------ 8.7/114.5 MB 2.0 MB/s eta 0:00:54
#      --- ------------------------------------ 8.7/114.5 MB 2.0 MB/s eta 0:00:54
#      --- ------------------------------------ 8.9/114.5 MB 1.9 MB/s eta 0:00:55
#      --- ------------------------------------
114.5 MB 1.5 MB/s eta 0:01:04
#      ----- --------------------------------- 17.3/114.5 MB 1.5 MB/s eta 0:01:04
#      ----- --------------------------------- 17.5/114.5 MB 1.5 MB/s eta 0:01:05
#      ----- --------------------------------- 17.5/114.5 MB 1.5 MB/s eta 0:01:05
#      ----- --------------------------------- 17.5/114.5 MB 1.5 MB/s eta 0:01:05
#      ----- --------------------------------- 17.6/114.5 MB 1.5 MB/s eta 0:01:05
#      ----- --------------------------------- 17.6/114.5 MB 1.5 MB/s eta 0:01:05
#      ----- --------------------------------- 17.6/114.5 MB 1.5 MB/s eta 0:01:05
#      ------ -------------------------------- 17.7/114.5 MB 1.5 MB/s eta 0:01:07
#      ------ -------------------------------- 17.9/114.5 MB 1.5 MB/s eta 0:01:07
#      ------ -------------------------------- 17.9/114.5 MB 1.5 MB/s eta 0:01:07
#      ------ -------------------------------- 18.0/114.5 MB 1.5 MB/s eta 0:01:07
#      ------ -------------------------------- 18.0/114.5 MB 1.5 MB/s eta 0:01:07
#      ------ -------------------------------- 18.0/114.5 MB 1.5 MB/s eta 0:01:07
#      ------ -------------------------------- 18.0/114.5 MB 1.5 MB/s eta 0:01:07
#      ------ -------------------------------- 18.2/114.5 MB 1.4 MB/s eta 0:01:08
#      ------ -------------------------------- 18.3/114.5 MB 1.4 MB/s eta 0:01:07
#      ------ -------------------------------- 18.3/114.5 MB 1.4 MB/s eta 0:01:07
#      ------ -------------------------------- 18.5/114.5 MB 1.4 MB/s eta 0:01:08
#      ------ -------------------------------- 18.6/114.5 MB 1.4 MB/s eta 0:01:07
#      ------ -------------------------------- 18.6/114.5 MB 1.4 MB/s eta 0:01:07
#      ------ -------------------------------- 18.6/114.5 MB 1.4 MB/s eta 0:01:08
#      ------ -------------------------------- 18.7/114.5 MB 1.4 MB/s eta 0:01:09
#      ------ -------------------------------- 18.8/114.5 MB 1.4 MB/s eta 0:01:09
#      ------ -------------------------------- 19.0/114.5 MB 1.4 MB/s eta 0:01:09
#      ------ -------------------------------- 19.0/114.5 MB 1.4 MB/s eta 0:01:09
#      ------ -------------------------------- 19.1/114.5 MB 1.4 MB/s eta 0:01:08
#      ------ -------------------------------- 19.1/114.5 MB 1.4 MB/s eta 0:01:08
#      ------ -------------------------------- 19.3/114.5 MB 1.4 MB/s eta 0:01:08
#      ------ -------------------------------- 19.3/114.5 MB 1.4 MB/s eta 0:01:08
#      ------ -------------------------------- 19.3/114.5 MB 1.4 MB/s eta 0:01:08
#      ------ -------------------------------- 19.5/114.5 MB 1.4 MB/s eta 0:01:07
#      ------ -------------------------------- 19.6/114.5 MB 1.4 MB/s eta 0:01:06
#      ------ -------------------------------- 19.7/114.5 MB 1.4 MB/s eta 0:01:07
#      ------ -------------------------------- 19.7/114.5 MB 1.4 MB/s eta 0:01:07
#      ------ -------------------------------- 19.9/114.5 MB 1.4 MB/s eta 0:01:06
#      ------ -------------------------------- 20.0/114.5 MB 1.4 MB/s eta 0:01:06
#      ------ -------------------------------- 20.0/114.5 MB 1.4 MB/s eta 0:01:07
#      ------ -------------------------------- 20.0/114.5 MB 1.4 MB/s eta 0:01:07
#      ------ -------------------------------- 20.2/114.5 MB 1.4 MB/s eta 0:01:07
#      ------ -------------------------------- 20.2/114.5 MB 1.4 MB/s eta 0:01:07
#      ------ -------------------------------- 20.2/114.5 MB 1.4 MB/s eta 0:01:07
#      ------ -------------------------------- 20.4/114.5 MB 1.4 MB/s eta 0:01:07
#      ------ -------------------------------- 20.5/114.5 MB 1.4 MB/s eta 0:01:07
#      ------ -------------------------------- 20.5/114.5 MB 1.4 MB/s eta 0:01:07
#      ------ -------------------------------- 20.5/114.5 MB 1.4 MB/s eta 0:01:07
#      ------- ------------------------------- 20.7/114.5 MB 1.4 MB/s eta 0:01:07
#      ------- ------------------------------- 20.7/114.5 MB 1.4 MB/s eta 0:01:07
#      ------- ------------------------------- 20.8/114.5 MB 1.4 MB/s eta 0:01:08
#      ------- ------------------------------- 20.8/114.5 MB 1.4 MB/s eta 0:01:08
#      ------- ------------------------------- 21.0/114.5 MB 1.4 MB/s eta 0:01:07
#      ------- ------------------------------- 21.0/114.5 MB 1.4 MB/s eta 0:01:07
#      ------- ------------------------------- 21.2/114.5 MB 1.4 MB/s eta 0:01:07
#      ------- ------------------------------- 21.2/114.5 MB 1.4 MB/s eta 0:01:07
#      ------- ------------------------------- 21.4/114.5 MB 1.4 MB/s eta 0:01:07
#      ------- ------------------------------- 21.4/114.5 MB 1.4 MB/s eta 0:01:07
#      ------- ------------------------------- 21.5/114.5 MB 1.4 MB/s eta 0:01:08
#      ------- ------------------------------- 21.6/114.5 MB 1.4 MB/s eta 0:01:08
#      ------- ------------------------------- 21.6/114.5 MB 1.4 MB/s eta 0:01:08
#      ------- ------------------------------- 21.6/114.5 MB 1.4 MB/s eta 0:01:08
#      ------- ------------------------------- 21.7/114.5 MB 1.4 MB/s eta 0:01:08
#      ------- ------------------------------- 21.7/114.5 MB 1.4 MB/s eta 0:01:08
#      ------- ------------------------------- 21.7/114.5 MB 1.4 MB/s eta 0:01:08
#      ------- ------------------------------- 21.7/114.5 MB 1.4 MB/s eta 0:01:08
#      ------- ------------------------------- 21.8/114.5 MB 1.3 MB/s eta 0:01:09
#      ------- ------------------------------- 21.9/114.5 MB 1.3 MB/s eta 0:01:10
#      ------- ------------------------------- 22.0/114.5 MB 1.3 MB/s eta 0:01:09
#      ------- ------------------------------- 22.0/114.5 MB 1.3 MB/s eta 0:01:09
#      ------- ------------------------------- 22.0/114.5 MB 1.3 MB/s eta 0:01:09
#      ------- ------------------------------- 22.2/114.5 MB 1.3 MB/s eta 0:01:10
#      ------- ------------------------------- 22.3/114.5 MB 1.3 MB/s eta 0:01:10
#      ------- ------------------------------- 22.3/114.5 MB 1.3 MB/s eta 0:01:10
#      ------- ------------------------------- 22.4/114.5 MB 1.3 MB/s eta 0:01:10
#      ------- ------------------------------- 22.6/114.5 MB 1.3 MB/s eta 0:01:10
#      ------- ------------------------------- 22.6/114.5 MB 1.3 MB/s eta 0:01:10
#      ------- ------------------------------- 22.7/114.5 MB 1.3 MB/s eta 0:01:11
#      ------- ------------------------------- 22.7/114.5 MB 1.3 MB/s eta 0:01:11
#      ------- ------------------------------- 22.8/114.5 MB 1.4 MB/s eta 0:01:08
#      ------- ------------------------------- 22.8/114.5 MB 1.4 MB/s eta 0:01:08
#      ------- ------------------------------- 22.9/114.5 MB 1.3 MB/s eta 0:01:09
#      ------- ------------------------------- 23.0/114.5 MB 1.4 MB/s eta 0:01:07
#      ------- ------------------------------- 23.2/114.5 MB 1.4 MB/s eta 0:01:06
#      ------- ------------------------------- 23.2/114.5 MB 1.4 MB/s eta 0:01:06
#      ------- ------------------------------- 23.2/114.5 MB 1.4 MB/s eta 0:01:06
#      ------- ------------------------------- 23.3/114.5 MB 1.4 MB/s eta 0:01:05
#      ------- ------------------------------- 23.3/114.5 MB 1.4 MB/s eta 0:01:04
#      ------- ------------------------------- 23.4/114.5 MB 1.4 MB/s eta 0:01:05
#      ------- ------------------------------- 23.4/114.5 MB 1.4 MB/s eta 0:01:05
#      ------- ------------------------------- 23.5/114.5 MB 1.5 MB/s eta 0:01:03
#      -------- ------------------------------ 23.6/114.5 MB 1.5 MB/s eta 0:01:03
#      -------- ------------------------------ 23.8/114.5 MB 1.5 MB/s eta 0:01:02
#      -------- ------------------------------ 23.8/114.5 MB 1.5 MB/s eta 0:01:01
#      -------- ------------------------------ 24
114.5 MB 1.7 MB/s eta 0:00:49
#      ---------- ---------------------------- 31.3/114.5 MB 1.7 MB/s eta 0:00:49
#      ---------- ---------------------------- 31.5/114.5 MB 1.7 MB/s eta 0:00:49
#      ---------- ---------------------------- 31.5/114.5 MB 1.7 MB/s eta 0:00:49
#      ---------- ---------------------------- 31.5/114.5 MB 1.7 MB/s eta 0:00:50
#      ---------- ---------------------------- 31.6/114.5 MB 1.7 MB/s eta 0:00:50
#      ---------- ---------------------------- 31.6/114.5 MB 1.7 MB/s eta 0:00:50
#      ---------- ---------------------------- 31.7/114.5 MB 1.7 MB/s eta 0:00:50
#      ---------- ---------------------------- 31.7/114.5 MB 1.7 MB/s eta 0:00:50
#      ---------- ---------------------------- 31.9/114.5 MB 1.7 MB/s eta 0:00:49
#      ---------- ---------------------------- 31.9/114.5 MB 1.7 MB/s eta 0:00:49
#      ---------- ---------------------------- 32.0/114.5 MB 1.8 MB/s eta 0:00:48
#      ---------- ---------------------------- 32.1/114.5 MB 1.7 MB/s eta 0:00:48
#      ----------- --------------------------- 32.3/114.5 MB 1.8 MB/s eta 0:00:47
#      ----------- --------------------------- 32.3/114.5 MB 1.8 MB/s eta 0:00:47
#      ----------- --------------------------- 32.3/114.5 MB 1.8 MB/s eta 0:00:47
#      ----------- --------------------------- 32.5/114.5 MB 1.8 MB/s eta 0:00:47
#      ----------- --------------------------- 32.6/114.5 MB 1.8 MB/s eta 0:00:47
#      ----------- --------------------------- 32.6/114.5 MB 1.8 MB/s eta 0:00:47
#      ----------- --------------------------- 32.8/114.5 MB 1.8 MB/s eta 0:00:47
#      ----------- --------------------------- 32.9/114.5 MB 1.8 MB/s eta 0:00:46
#      ----------- --------------------------- 33.0/114.5 MB 1.8 MB/s eta 0:00:46
#      ----------- --------------------------- 33.0/114.5 MB 1.8 MB/s eta 0:00:46
#      ----------- --------------------------- 33.1/114.5 MB 1.8 MB/s eta 0:00:46
#      ----------- --------------------------- 33.2/114.5 MB 1.8 MB/s eta 0:00:46
#      ----------- --------------------------- 33.2/114.5 MB 1.8 MB/s eta 0:00:46
#      ----------- --------------------------- 33.4/114.5 MB 1.8 MB/s eta 0:00:46
#      ----------- --------------------------- 33.5/114.5 MB 1.8 MB/s eta 0:00:46
#      ----------- --------------------------- 33.6/114.5 MB 1.8 MB/s eta 0:00:46
#      ----------- --------------------------- 33.6/114.5 MB 1.8 MB/s eta 0:00:46
#      ----------- --------------------------- 33.8/114.5 MB 1.8 MB/s eta 0:00:45
#      ----------- --------------------------- 33.8/114.5 MB 1.8 MB/s eta 0:00:45
#      ----------- --------------------------- 33.9/114.5 MB 1.8 MB/s eta 0:00:45
#      ----------- --------------------------- 33.9/114.5 MB 1.8 MB/s eta 0:00:45
#      ----------- --------------------------- 34.1/114.5 MB 1.8 MB/s eta 0:00:46
#      ----------- --------------------------- 34.1/114.5 MB 1.8 MB/s eta 0:00:46
#      ----------- --------------------------- 34.1/114.5 MB 1.8 MB/s eta 0:00:46
#      ----------- --------------------------- 34.2/114.5 MB 1.8 MB/s eta 0:00:46
#      ----------- --------------------------- 34.4/114.5 MB 1.8 MB/s eta 0:00:46
#      ----------- --------------------------- 34.4/114.5 MB 1.8 MB/s eta 0:00:46
#      ----------- --------------------------- 34.5/114.5 MB 1.8 MB/s eta 0:00:45
#      ----------- --------------------------- 34.6/114.5 MB 1.8 MB/s eta 0:00:45
#      ----------- --------------------------- 34.6/114.5 MB 1.8 MB/s eta 0:00:45
#      ----------- --------------------------- 34.6/114.5 MB 1.7 MB/s eta 0:00:46
#      ----------- --------------------------- 34.7/114.5 MB 1.8 MB/s eta 0:00:46
#      ----------- --------------------------- 34.8/114.5 MB 1.8 MB/s eta 0:00:45
#      ----------- --------------------------- 34.8/114.5 MB 1.8 MB/s eta 0:00:45
#      ----------- --------------------------- 34.8/114.5 MB 1.7 MB/s eta 0:00:46
#      ----------- --------------------------- 35.0/114.5 MB 1.8 MB/s eta 0:00:46
#      ----------- --------------------------- 35.1/114.5 MB 1.8 MB/s eta 0:00:46
#      ----------- --------------------------- 35.2/114.5 MB 1.8 MB/s eta 0:00:45
#      ----------- --------------------------- 35.2/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------ -------------------------- 35.3/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------ -------------------------- 35.3/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------ -------------------------- 35.4/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------ -------------------------- 35.5/114.5 MB 1.8 MB/s eta 0:00:46
#      ------------ -------------------------- 35.7/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------ -------------------------- 35.7/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------ -------------------------- 35.7/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------ -------------------------- 35.9/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------ -------------------------- 35.9/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------ -------------------------- 36.0/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------ -------------------------- 36.0/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------ -------------------------- 36.1/114.5 MB 1.7 MB/s eta 0:00:45
#      ------------ -------------------------- 36.2/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------ -------------------------- 36.2/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------ -------------------------- 36.3/114.5 MB 1.7 MB/s eta 0:00:45
#      ------------ -------------------------- 36.5/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------ -------------------------- 36.5/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------ -------------------------- 36.6/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------ -------------------------- 36.7/114.5 MB 1.7 MB/s eta 0:00:45
#      ------------ -------------------------- 36.8/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------ -------------------------- 36.8/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------ -------------------------- 36.8/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------ -------------------------- 37.0/114.5 MB 1.7 MB/s eta 0:00:45
#      ------------ -------------------------- 37.0/114.5 MB 1.7 MB/s eta 0:00:45
#      ------------ -------------------------- 37.2/114.5 MB 1.7 MB/s eta 0:00:45
#      ------------ -------------------------- 37.3/114.5 MB 1.7 MB/s eta 0:00:45
#      ------------ -------------------------- 37.3/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------ -------------------------- 37.3/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------ -------------------------- 37.4/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------ -------------------------- 37.6/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------ -------------------------- 37.6/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------ -------------------------- 37.6/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------ -------------------------- 37.6/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------ -------------------------- 37.7/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------ -------------------------- 37.7/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------ -------------------------- 37.9/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------ -------------------------- 37.9/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------ -------------------------- 38.0/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------ -------------------------- 38.1/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------- ------------------------- 38.2/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------- ------------------------- 38.3/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------- ------------------------- 38.3/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------- ------------------------- 38.5/114.5 MB 1.6 MB/s eta 0:00:47
#      ------------- ------------------------- 38.6/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------- ------------------------- 38.7/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------- ------------------------- 38.7/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------- ------------------------- 38.9/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------- ------------------------- 38.9/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------- ------------------------- 39.0/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------- ------------------------- 39.0/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------- ------------------------- 39.2/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------- ------------------------- 39.2/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------- ------------------------- 39.3/114.5 MB 1.7 MB/s eta 0:00:46
#      ------------- ------------------------- 39.5/114.5 MB 1.7 MB/s eta 0:00:45
#      ------------- ------------------------- 39.6/114.5 MB 1.7 MB/s eta 0:00:45
#      ------------- ------------------------- 39.6/114.5 MB 1.7 MB/s eta 0:00:45
#      ------------- ------------------------- 39.6/114.5 MB 1.7 MB/s eta 0:00:45
#      ------------- ------------------------- 39.8/114.5 MB 1.7 MB/s eta 0:00:45
#      ------------- ------------------------- 39.8/114.5 MB 1.7 MB/s eta 0:00:45
#      ------------- ------------------------- 39.9/114.5 MB 1.7 MB/s eta 0:00:45
#      ------------- ------------------------- 39.9/114.5 MB 1.7 MB/s eta 0:00:45
#      ------------- ------------------------- 40.1/114.5 MB 1.7 MB/s eta 0:00:45
#      ------------- ------------------------- 40.1/114.5 MB 1.7 MB/s eta 0:00:45
#      ------------- ------------------------- 40.2/114.5 MB 1.7 MB/s eta 0:00:45
#      ------------- ------------------------- 40.3/114.5 MB 1.7 MB/s eta 0:00:45
#      ------------- ------------------------- 40.3/114.5 MB 1.7 MB/s eta 0:00:45
#      ------------- ------------------------- 40.3/114.5 MB 1.7 MB/s eta 0:00:45
#      ------------- ------------------------- 40.4/114.5 MB 1.7 MB/s eta 0:00:45
#      ------------- ------------------------- 40.7/114.5 MB 1.7 MB/s eta 0:00:45
#      ------------- ------------------------- 40.7/114.5 MB 1.7 MB/s eta 0:00:45
#      ------------- ------------------------- 40.8/114.5 MB 1.7 MB/s eta 0:00:45
#      ------------- ------------------------- 41.0/114.5 MB 1.7 MB/s eta 0:00:45
#      -------------- ------------------------ 41.2/114.5 MB 1.7 MB/s eta 0:00:44
#      -------------- ------------------------ 41.2/114.5 MB 1.7 MB/s eta 0:00:44
#      -------------- ------------------------ 41.2/114.5 MB 1.7 MB/s eta 0:00:44
#      -------------- ------------------------ 41.4/114.5 MB 1.7 MB/s eta 0:00:43
#      -------------- ------------------------ 41.5/114.5 MB 1.7 MB/s eta 0:00:43
#      -------------- ------------------------ 41.6/114.5 MB 1.7 MB/s eta 0:00:43
#      -------------- ------------------------ 41.6/114.5 MB 1.7 MB/s eta 0:00:43
#      -------------- ------------------------ 41.9/114.5 MB 1.7 MB/s eta 0:00:42
#      -------------- ------------------------ 41.9/114.5 MB 1.7 MB/s eta 0:00:42
#      -------------- ------------------------ 41.9/114.5 MB 1.7 MB/s eta 0:00:43
#      -------------- ------------------------ 42.1/114.5 MB 1.7 MB/s eta 0:00:42
#      -------------- ------------------------ 42.3/114.5 MB 1.8 MB/s eta 0:00:42
#      -------------- ------------------------ 42.3/114.5 MB 1.8 MB/s eta 0:00:42
#      -------------- ------------------------ 42.3/114.5 MB 1.8 MB/s eta 0:00:42
#      -------------- ------------------------ 42.5/114.5 MB 1.7 MB/s eta 0:00:42
#      -------------- ------------------------ 42.5/114.5 MB 1.7 MB/s eta 0:00:42
#      -------------- ------------------------ 42.6/114.5 MB 1.8 MB/s eta 0:00:41
#      -------------- ------------------------ 42.6/114.5 MB 1.8 MB/s eta 0:00:41
#      -------------- ------------------------ 42.8/114.5 MB 1.7 MB/s eta 0:00:42
#      -------------- ------------------------ 42.8/114.5 MB 1.7 MB/s eta 0:00:42
#      -------------- ------------------------ 42.8/114.5 MB 1.7 MB/s eta 0:00:42
#      -------------- ------------------------ 43.0/114.5 MB 1.7 MB/s eta 0:00:42
#      -------------- ------------------------ 43.2/114.5 MB 1.8 MB/s eta 0:00:41
#      -------------- ------------------------ 43.2/114.5 MB 1.8 MB/s eta 0:00:41
#      -------------- ------------------------
---------------------------------------- 0.0/625.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/625.2 kB ? eta -:--:--
#      --- ----------------------------------- 61.4/625.2 kB 3.4 MB/s eta 0:00:01
#      --- ----------------------------------- 61.4/625.2 kB 3.4 MB/s eta 0:00:01
#      --- ----------------------------------- 61.4/625.2 kB 3.4 MB/s eta 0:00:01
#      --- ----------------------------------- 61.4/625.2 kB 3.4 MB/s eta 0:00:01
#      ---------- ------------------------- 174.1/625.2 kB 751.6 kB/s eta 0:00:01
#      ----------- ------------------------ 194.6/625.2 kB 737.3 kB/s eta 0:00:01
#      -------------- --------------------- 256.0/625.2 kB 927.4 kB/s eta 0:00:01
#      -------------- --------------------- 256.0/625.2 kB 927.4 kB/s eta 0:00:01
#      ---------------------- ------------- 399.4/625.2 kB 997.7 kB/s eta 0:00:01
#      ------------------------ ----------- 419.8/625.2 kB 937.3 kB/s eta 0:00:01
#      ------------------------- ---------- 440.3/625.2 kB 860.2 kB/s eta 0:00:01
#      ----------------------------------- -- 583.7/625.2 kB 1.1 MB/s eta 0:00:01
#      -------------------------------------  624.6/625.2 kB 1.1 MB/s eta 0:00:01
#      -------------------------------------- 625.2/625.2 kB 1.0 MB/s eta 0:00:00
# Collecting fsspec>=2023.5.0
#   Downloading fsspec-2026.3.0-py3-none-any.whl (202 kB)
#      ---------------------------------------- 0.0/202.6 kB ? eta -:--:--
#      ---------------------------- --------- 153.6/202.6 kB 9.0 MB/s eta 0:00:01
#      ---------------------------- --------- 153.6/202.6 kB 9.0 MB/s eta 0:00:01
#      -------------------------------------- 202.6/202.6 kB 1.7 MB/s eta 0:00:00
# Collecting pyyaml>=5.1
#   Downloading pyyaml-6.0.3-cp310-cp310-win_amd64.whl (158 kB)
#      ---------------------------------------- 0.0/158.6 kB ? eta -:--:--
#      ---------------------------------- --- 143.4/158.6 kB 8.3 MB/s eta 0:00:01
#      ------------------------------------ - 153.6/158.6 kB 2.3 MB/s eta 0:00:01
#      -------------------------------------- 158.6/158.6 kB 1.4 MB/s eta 0:00:00
# Collecting httpx<1,>=0.23.0
#   Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Requirement already satisfied: packaging>=20.9 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (26.0)
# Collecting hf-xet<2.0.0,>=1.4.2
#   Downloading hf_xet-1.4.2-cp37-abi3-win_amd64.whl (3.7 MB)
#      ---------------------------------------- 0.0/3.7 MB ? eta -:--:--
#       --------------------------------------- 0.1/3.7 MB ? eta -:--:--
#      - -------------------------------------- 0.1/3.7 MB 1.3 MB/s eta 0:00:03
#      -- ------------------------------------- 0.2/3.7 MB 1.5 MB/s eta 0:00:03
#      -- ------------------------------------- 0.2/3.7 MB 1.6 MB/s eta 0:00:03
#      --- ------------------------------------ 0.3/3.7 MB 1.5 MB/s eta 0:00:03
#      ---- ----------------------------------- 0.4/3.7 MB 1.5 MB/s eta 0:00:03
#      ----- ---------------------------------- 0.5/3.7 MB 1.7 MB/s eta 0:00:02
#      ------ --------------------------------- 0.6/3.7 MB 1.6 MB/s eta 0:00:02
#      ------ --------------------------------- 0.6/3.7 MB 1.6 MB/s eta 0:00:02
#      -------- ------------------------------- 0.8/3.7 MB 1.7 MB/s eta 0:00:02
#      -------- ------------------------------- 0.8/3.7 MB 1.6 MB/s eta 0:00:02
#      --------- ------------------------------ 0.9/3.7 MB 1.7 MB/s eta 0:00:02
#      --------- ------------------------------ 0.9/3.7 MB 1.6 MB/s eta 0:00:02
#      ----------- ---------------------------- 1.1/3.7 MB 1.6 MB/s eta 0:00:02
#      ----------- ---------------------------- 1.1/3.7 MB 1.6 MB/s eta 0:00:02
#      ------------ --------------------------- 1.1/3.7 MB 1.6 MB/s eta 0:00:02
#      ------------ --------------------------- 1.1/3.7 MB 1.6 MB/s eta 0:00:02
#      ------------- -------------------------- 1.2/3.7 MB 1.4 MB/s eta 0:00:02
#      ------------- -------------------------- 1.3/3.7 MB 1.5 MB/s eta 0:00:02
#      ------------- -------------------------- 1.3/3.7 MB 1.5 MB/s eta 0:00:02
#      --------------- ------------------------ 1.4/3.7 MB 1.5 MB/s eta 0:00:02
#      --------------- ------------------------ 1.4/3.7 MB 1.4 MB/s eta 0:00:02
#      ----------------- ---------------------- 1.6/3.7 MB 1.5 MB/s eta 0:00:02
#      ----------------- ---------------------- 1.6/3.7 MB 1.5 MB/s eta 0:00:02
#      ------------------- -------------------- 1.8/3.7 MB 1.5 MB/s eta 0:00:02
#      ------------------- -------------------- 1.8/3.7 MB 1.5 MB/s eta 0:00:02
#      -------------------- ------------------- 1.8/3.7 MB 1.5 MB/s eta 0:00:02
#      -------------------- ------------------- 1.9/3.7 MB 1.5 MB/s eta 0:00:02
#      --------------------- ------------------ 2.0/3.7 MB 1.5 MB/s eta 0:00:02
#      ---------------------- ----------------- 2.1/3.7 MB 1.5 MB/s eta 0:00:02
#      ---------------------- ----------------- 2.1/3.7 MB 1.5 MB/s eta 0:00:02
#      ----------------------- ---------------- 2.1/3.7 MB 1.4 MB/s eta 0:00:02
#      ------------------------ --------------- 2.3/3.7 MB 1.5 MB/s eta 0:00:01
#      ------------------------- -------------- 2.3/3.7 MB 1.5 MB/s eta 0:00:01
#      ------------------------- -------------- 2.3/3.7 MB 1.5 MB/s eta 0:00:01
#      --------------------------- ------------ 2.5/3.7 MB 1.5 MB/s eta 0:00:01
#      --------------------------- ------------ 2.5/3.7 MB 1.5 MB/s eta 0:00:01
#      ---------------------------- ----------- 2.6/3.7 MB 1.5 MB/s eta 0:00:01
#      ----------------------------- ---------- 2.7/3.7 MB 1.5 MB/s eta 0:00:01
#      ------------------------------- -------- 2.9/3.7 MB 1.6 MB/s eta 0:00:01
#      -------------------------------- ------- 3.0/3.7 MB 1.6 MB/s eta 0:00:01
#      -------------------------------- ------- 3.0/3.7 MB 1.6 MB/s eta 0:00:01
#      -------------------------------- ------- 3.0/3.7 MB 1.5 MB/s eta 0:00:01
#      --------------------------------- ------ 3.1/3.7 MB 1.5 MB/s eta 0:00:01
#      --------------------------------- ------ 3.1/3.7 MB 1.5 MB/s eta 0:00:01
#      ---------------------------------- ----- 3.1/3.7 MB 1.5 MB/s eta 0:00:01
#      ----------------------------------- ---- 3.3/3.7 MB 1.5 MB/s eta 0:00:01
#      ----------------------------------- ---- 3.3/3.7 MB 1.5 MB/s eta 0:00:01
#      ----------------------------------- ---- 3.3/3.7 MB 1.4 MB/s eta 0:00:01
#      ------------------------------------- -- 3.4/3.7 MB 1.5 MB/s eta 0:00:01
#      ------------------------------------- -- 3.5/3.7 MB 1.5 MB/s eta 0:00:01
#      -------------------------------------- - 3.5/3.7 MB 1.5 MB/s eta 0:00:01
#      -------------------------------------- - 3.6/3.7 MB 1.4 MB/s eta 0:00:01
#      ---------------------------------------- 3.7/3.7 MB 1.4 MB/s eta 0:00:00
# Collecting typer
#   Downloading typer-0.24.1-py3-none-any.whl (56 kB)
#      ---------------------------------------- 0.0/56.1 kB ? eta -:--:--
#      ---------------------------------------- 56.1/56.1 kB 2.9 MB/s eta 0:00:00
# Collecting filelock>=3.10.0
#   Downloading filelock-3.25.2-py3-none-any.whl (26 kB)
# Collecting jinja2
#   Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Collecting networkx>=2.5.1
#   Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#      ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#      -- ------------------------------------- 0.1/1.7 MB 737.3 kB/s eta 0:00:03
#      --- ------------------------------------ 0.2/1.7 MB 919.0 kB/s eta 0:00:02
#      --- ------------------------------------ 0.2/1.7 MB 919.0 kB/s eta 0:00:02
#      ------ --------------------------------- 0.3/1.7 MB 1.0 MB/s eta 0:00:02
#      ------ --------------------------------- 0.3/1.7 MB 930.9 kB/s eta 0:00:02
#      ------ --------------------------------- 0.3/1.7 MB 930.9 kB/s eta 0:00:02
#      ------ --------------------------------- 0.3/1.7 MB 930.9 kB/s eta 0:00:02
#      ------------ --------------------------- 0.5/1.7 MB 1.2 MB/s eta 0:00:01
#      ------------- -------------------------- 0.6/1.7 MB 1.1 MB/s eta 0:00:02
#      -------------- ------------------------- 0.6/1.7 MB 1.1 MB/s eta 0:00:01
#      -------------- ------------------------- 0.6/1.7 MB 1.1 MB/s eta 0:00:01
#      -------------- ------------------------- 0.6/1.7 MB 1.1 MB/s eta 0:00:01
#      --------------- ------------------------ 0.7/1.7 MB 868.9 kB/s eta 0:00:02
#      ----------------- ---------------------- 0.8/1.7 MB 919.5 kB/s eta 0:00:02
#      ------------------ --------------------- 0.8/1.7 MB 881.6 kB/s eta 0:00:02
#      -------------------- ------------------- 0.9/1.7 MB 841.1 kB/s eta 0:00:01
#      -------------------- ------------------- 0.9/1.7 MB 841.1 kB/s eta 0:00:01
#      ----------------------- ---------------- 1.0/1.7 MB 877.0 kB/s eta 0:00:01
#      ----------------------- ---------------- 1.0/1.7 MB 877.0 kB/s eta 0:00:01
#      -------------------------- ------------- 1.2/1.7 MB 905.9 kB/s eta 0:00:01
#      -------------------------- ------------- 1.2/1.7 MB 905.9 kB/s eta 0:00:01
#      --------------------------- ------------ 1.2/1.7 MB 876.2 kB/s eta 0:00:01
#      ---------------------------- ----------- 1.2/1.7 MB 893.7 kB/s eta 0:00:01
#      -------------------------------- ------- 1.4/1.7 MB 958.5 kB/s eta 0:00:01
#      --------------------------------- ------ 1.4/1.7 MB 942.1 kB/s eta 0:00:01
#      --------------------------------- ------ 1.4/1.7 MB 942.1 kB/s eta 0:00:01
#      ------------------------------------- -- 1.6/1.7 MB 998.6 kB/s eta 0:00:01
#      ---------------------------------------  1.7/1.7 MB 1.0 MB/s eta 0:00:01
#      ---------------------------------------- 1.7/1.7 MB 978.9 kB/s eta 0:00:00
# Collecting sympy>=1.13.3
#   Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Requirement already satisfied: setuptools<82 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.11.0->sentence-transformers) (65.5.0)
# Requirement already satisfied: colorama in c:\users\admin\appdata\roaming\python\python310\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Collecting tokenizers<=0.23.0,>=0.22.0
#   Using cached tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
# Collecting regex>=2025.10.22
#   Downloading regex-2026.3.32-cp310-cp310-win_amd64.whl (278 kB)
#      ---------------------------------------- 0.0/278.6 kB ? eta -:--:--
#      ---------------- --------------------- 122.9/278.6 kB 2.4 MB/s eta 0:00:01
#      ------------------------------------ - 266.2/278.6 kB 2.7 MB/s eta 0:00:01
#      -------------------------------------- 278.6/278.6 kB 2.1 MB/s eta 0:00:00
# Collecting safetensors>=0.4.3
#   Using cached safetensors-0.7.0-cp38-abi3-win_amd64.whl (341 kB)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.3)
# Requirement already satisfied: idna in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (3.11)
# Collecting anyio
#   Downloading anyio-4.13.0-py3-none-any.whl (114 kB)
#      ---------------------------------------- 0.0/114.4 kB ? eta -:--:--
#      -------------------------------------- 114.4/114.4 kB 3.3 MB/s eta 0:00:00
# Collecting httpcore==1.*
#   Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Requirement already satisfied: certifi in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (2026.1.4)
# Collecting h11>=0.16
#   Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Collecting mpmath<1.4,>=1.1.0
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: rich>=12.3.0 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from typer->huggingface-hub>=0.20.0->sentence-transformers) (14.3.2)
# Collecting shellingham>=1.3.0
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Collecting annotated-doc>=0.0.2
#   Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Collecting click>=8.2.1
#   Using cached click-8.3.1-py3-none-any.whl (108 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from rich>=12.3.0->typer->huggingface-hub>=0.20.0->sentence-transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from rich>=12.3.0->typer->huggingface-hub>=0.20.0->sentence-transformers) (2.19.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\admin\appdata\roaming\python\python310\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub>=0.20.0->sentence-transformers) (0.1.2)
# Installing collected packages: mpmath, tqdm, sympy, shellingham, safetensors, regex, pyyaml, networkx, jinja2, hf-xet, h11, fsspec, filelock, click, annotated-doc, torch, httpcore, anyio, typer, httpx, huggingface-hub, tokenizers, transformers, sentence-transformers
# Successfully installed annotated-doc-0.0.4 anyio-4.13.0 click-8.3.1 filelock-3.25.2 fsspec-2026.3.0 h11-0.16.0 hf-xet-1.4.2 httpcore-1.0.9 httpx-0.28.1 huggingface-hub-1.8.0 jinja2-3.1.6 mpmath-1.3.0 networkx-3.4.2 pyyaml-6.0.3 regex-2026.3.32 safetensors-0.7.0 sentence-transformers-5.3.0 shellingham-1.5.4 sympy-1.14.0 tokenizers-0.22.2 torch-2.11.0 tqdm-4.67.3 transformers-5.4.0 typer-0.24.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sentence_transformers import SentenceTransformer

# Load the pre-trained model
print("Loading the embedding model...")
model = SentenceTransformer('all-MiniLM-L6-v2')
print("Model loaded successfully!")
# Out:
# Loading the embedding model...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 3741.77it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Model loaded successfully!
